# %%
# マーカーの種類と色を設定する
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

days = np.arange(1, 11)
weight = np.array([10, 14, 18, 20, 18, 16, 17, 18, 20, 17])

# 表示を設定
plt.ylim([0, weight.max() + 1])
plt.xlabel('days')
plt.ylabel('weight')

# 円マーカーを黒でプロットし折れ線グラフを作成
plt.plot(days, weight, marker='o', markerfacecolor='k')

plt.show()

# %%
# 線のスタイルと色を設定する
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

days = np.arange(1, 11)
weight = np.array([10, 14, 18, 20, 18, 16, 17, 18, 20, 17])

# 表示を設定
plt.ylim([0, weight.max() + 1])
plt.xlabel('days')
plt.ylabel('weight')

# 円マーカーを黒でプロットし青の破線の折れ線グラフを作成
plt.plot(days, weight, linestyle='--', color='b', marker='o', markerfacecolor='k')

plt.show()
